# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
df = pd.read_csv("../data/customer_churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
# ...

# %%
df["Churn"].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
import sys
print(sys.executable)

# %pip install seaborn
# Out:
# d:\VV\python.exe
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df = pd.read_csv("../data/customer_churn.csv")
df.head()

# %% [markdown]
#  ## Day 2 - Data Understanding
#
# In this section, we explore the structure, data types, missing values,
# duplicates, unique values, and target distribution of the dataset.

# %%
df.shape
# Out:
# (7043, 21)

# %% [markdown]
# The dataset contains 7,043 customer records and 21 features.

# %%
df.columns.tolist()
# Out:
# ['customerID',
#  'gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'MonthlyCharges',
#  'TotalCharges',
#  'Churn']

# %%
df.dtypes
# Out:
# customerID              str
# gender                  str
# SeniorCitizen         int64
# Partner                 str
# Dependents              str
# tenure                int64
# PhoneService            str
# MultipleLines           str
# InternetService         str
# OnlineSecurity          str
# OnlineBackup            str
# DeviceProtection        str
# TechSupport             str
# StreamingTV             str
# StreamingMovies         str
# Contract                str
# PaperlessBilling        str
# PaymentMethod           str
# MonthlyCharges      float64
# TotalCharges            str
# Churn                   str
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
# ...

# %%
df["TotalCharges"].dtype
# Out:
# <StringDtype(na_value=nan)>

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
(df == " ").sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["customerID"].nunique()
# Out:
# 7043

# %%
len(df)
# Out:
# 7043

# %%
categorical_columns = df.select_dtypes(include="object").columns

for column in categorical_columns:
    print(f"\n{column}")
    print(df[column].value_counts())
# Out:
# customerID
# customerID
# 7590-VHVEG    1
# 5575-GNVDE    1
# 3668-QPYBK    1
# 7795-CFOCW    1
# 9237-HQITU    1
#              ..
# 6840-RESVB    1
# 2234-XADUH    1
# 4801-JZAZL    1
# 8361-LTMKD    1
# 3186-AJIEK    1
# Name: count, Length: 7043, dtype: int64
#
# gender
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64
#
# Partner
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64
#
# Dependents
# Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64
#
# PhoneService
# PhoneService
# Yes    6361
# No      682
# Name: count, dtype: int64
#
# MultipleLines
# MultipleLines
# No                  3390
# Yes                 2971
# No phone service     682
# Name: count, dtype: int64
#
# InternetService
# InternetService
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64
#
# OnlineSecurity
# OnlineSecurity
# No                     3498
# Yes                    2019
# No internet service    1526
# ...

# %%
df["Churn"].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df["Churn"].value_counts(normalize=True) * 100
# Out:
# Churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.describe(include="all").T
# Out:
#                    count unique               top  freq       mean        std  \
# customerID          7043   7043        7590-VHVEG     1        NaN        NaN
# gender              7043      2              Male  3555        NaN        NaN
# SeniorCitizen     7043.0    NaN               NaN   NaN   0.162147   0.368612
# Partner             7043      2                No  3641        NaN        NaN
# Dependents          7043      2                No  4933        NaN        NaN
# tenure            7043.0    NaN               NaN   NaN  32.371149  24.559481
# PhoneService        7043      2               Yes  6361        NaN        NaN
# MultipleLines       7043      3                No  3390        NaN        NaN
# InternetService     7043      3       Fiber optic  3096        NaN        NaN
# OnlineSecurity      7043      3                No  3498        NaN        NaN
# OnlineBackup        7043      3                No  3088        NaN        NaN
# ...

# %% [markdown]
# ## Initial Observations
#
# - Dataset contains 7,043 customer records and 21 columns.
# - The target variable is `Churn`.
# - Checked the dataset for missing values and blank values.
# - Checked for duplicate customer records.
# - Reviewed numerical and categorical features.
# - Identified columns that may require data type conversion.
# - Data cleaning will be performed in the next stage.

# %% [markdown]
# ## Day 3 - Data Cleaning
#
# In this section, we clean the dataset by handling missing values,
# correcting data types, checking duplicates, and removing unnecessary columns.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("../data/customer_churn.csv")

# %%
df["TotalCharges"].dtype
# Out:
# <StringDtype(na_value=nan)>

# %%
(df["TotalCharges"] == " ").sum()
# Out:
# np.int64(11)

# %%
df["TotalCharges"] = pd.to_numeric(
    df["TotalCharges"],
    errors="coerce"
)

# %%
df["TotalCharges"].isnull().sum()
# Out:
# np.int64(11)

# %%
df[df["TotalCharges"].isnull()]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %%
df = df.dropna(subset=["TotalCharges"])

# %%
df["TotalCharges"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["customerID"].nunique()
# Out:
# 7032

# %%
categorical_cols = df.select_dtypes(include="object").columns

for col in categorical_cols:
    print(f"{col}: {df[col].unique()}")
    print()
# Out:
# customerID: <ArrowStringArray>
# ['7590-VHVEG', '5575-GNVDE', '3668-QPYBK', '7795-CFOCW', '9237-HQITU',
#  '9305-CDSKC', '1452-KIOVK', '6713-OKOMC', '7892-POOKP', '6388-TABGU',
#  ...
#  '9767-FFLEM', '0639-TSIQW', '8456-QDAVC', '7750-EYXWZ', '2569-WGERO',
#  '6840-RESVB', '2234-XADUH', '4801-JZAZL', '8361-LTMKD', '3186-AJIEK']
# Length: 7032, dtype: str
#
# gender: <ArrowStringArray>
# ['Female', 'Male']
# Length: 2, dtype: str
#
# Partner: <ArrowStringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
#
# Dependents: <ArrowStringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
#
# PhoneService: <ArrowStringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
#
# MultipleLines: <ArrowStringArray>
# ['No phone service', 'No', 'Yes']
# Length: 3, dtype: str
#
# InternetService: <ArrowStringArray>
# ['DSL', 'Fiber optic', 'No']
# Length: 3, dtype: str
#
# OnlineSecurity: <ArrowStringArray>
# ['No', 'Yes', 'No internet service']
# Length: 3, dtype: str
#
# OnlineBackup: <ArrowStringArray>
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7032.000000  7032.000000     7032.000000   7032.000000
# mean        0.162400    32.421786       64.798208   2283.300441
# std         0.368844    24.545260       30.085974   2266.771362
# min         0.000000     1.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.587500    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.862500   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df[["tenure", "MonthlyCharges", "TotalCharges"]].describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  7032.000000     7032.000000   7032.000000
# mean     32.421786       64.798208   2283.300441
# std      24.545260       30.085974   2266.771362
# min       1.000000       18.250000     18.800000
# 25%       9.000000       35.587500    401.450000
# 50%      29.000000       70.350000   1397.475000
# 75%      55.000000       89.862500   3794.737500
# max      72.000000      118.750000   8684.800000

# %%
print("Dataset shape:", df.shape)
print("Missing values:", df.isnull().sum().sum())
print("Duplicates:", df.duplicated().sum())
print("\nData types:")
print(df.dtypes)
# Out:
# Dataset shape: (7032, 21)
# Missing values: 0
# Duplicates: 0
#
# Data types:
# customerID              str
# gender                  str
# SeniorCitizen         int64
# Partner                 str
# Dependents              str
# tenure                int64
# PhoneService            str
# MultipleLines           str
# InternetService         str
# OnlineSecurity          str
# OnlineBackup            str
# DeviceProtection        str
# TechSupport             str
# StreamingTV             str
# StreamingMovies         str
# Contract                str
# PaperlessBilling        str
# PaymentMethod           str
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                   str
# dtype: object

# %%
df.to_csv("../data/customer_churn_cleaned.csv", index=False)

# %% [markdown]
# ## Data Cleaning Summary
#
# - Inspected missing and blank values.
# - Converted `TotalCharges` to numeric format.
# - Handled missing values in `TotalCharges`.
# - Checked the dataset for duplicate records.
# - Reviewed categorical values for inconsistencies.
# - Preserved `customerID` for EDA but will exclude it from model features.
# - Saved the cleaned dataset separately from the raw dataset.

# %% [markdown]
# ##  Exploratory Data Analysis
#
# In this section, we visualize customer churn patterns and explore
# relationships between customer characteristics and churn.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/customer_churn_cleaned.csv")

# %%
sns.countplot(data=df, x="Churn")
plt.title("Customer Churn Distribution")
plt.xlabel("Churn")
plt.ylabel("Number of Customers")
plt.show()

# %%
df["Churn"].value_counts(normalize=True) * 100
# Out:
# Churn
# No     73.421502
# Yes    26.578498
# Name: proportion, dtype: float64

# %% [markdown]
# ### Observation: Customer Churn Distribution
#
# - Approximately **73.42%** of customers did not churn, while **26.58%** of customers churned.
# - The dataset contains noticeably more non-churn customers than churn customers.
# - This indicates a **moderate class imbalance** in the target variable (`Churn`).
# - Because of this imbalance, model performance should not be evaluated using accuracy alone. Metrics such as **Precision, Recall, F1-score, and ROC-AUC** will also be considered during model evaluation.

# %%
sns.countplot(data=df, x="Contract", hue="Churn")

plt.title("Customer Churn by Contract Type")
plt.xlabel("Contract Type")
plt.ylabel("Number of Customers")
plt.xticks(rotation=15)

plt.show()

# %%
pd.crosstab(
    df["Contract"],
    df["Churn"],
    normalize="index"
) * 100
# Out:
# Churn                  No        Yes
# Contract
# Month-to-month  57.290323  42.709677
# One year        88.722826  11.277174
# Two year        97.151335   2.848665

# %%
sns.countplot(data=df, x="gender", hue="Churn")

plt.title("Customer Churn by Gender")
plt.xlabel("Gender")
plt.ylabel("Number of Customers")

plt.show()

# %%
sns.countplot(data=df, x="SeniorCitizen", hue="Churn")

plt.title("Customer Churn by Senior Citizen Status")
plt.xlabel("Senior Citizen")
plt.ylabel("Number of Customers")

plt.show()

# %%
sns.countplot(data=df, x="Partner", hue="Churn")

plt.title("Customer Churn by Partner Status")
plt.xlabel("Partner")
plt.ylabel("Number of Customers")

plt.show()

# %%
sns.countplot(data=df, x="Dependents", hue="Churn")

plt.title("Customer Churn by Dependents")
plt.xlabel("Dependents")
plt.ylabel("Number of Customers")

plt.show()

# %%
plt.figure(figsize=(10, 5))

sns.countplot(
    data=df,
    x="PaymentMethod",
    hue="Churn"
)

plt.title("Customer Churn by Payment Method")
plt.xlabel("Payment Method")
plt.ylabel("Number of Customers")
plt.xticks(rotation=30)

plt.show()

# %%
pd.crosstab(
    df["PaymentMethod"],
    df["Churn"],
    normalize="index"
) * 100
# Out:
# Churn                             No        Yes
# PaymentMethod
# Bank transfer (automatic)  83.268482  16.731518
# Credit card (automatic)    84.746877  15.253123
# Electronic check           54.714588  45.285412
# Mailed check               80.798005  19.201995

# %% [markdown]
# ##  Key Observations
#
# 1. The dataset contains more non-churn customers than churn customers.
# 2. Contract type shows differences in churn patterns.
# 3. Churn patterns vary across payment methods.
# 4. Demographic variables such as gender, senior citizen status,
#    partner status, and dependents were also examined.
#
# These observations describe associations in the dataset and do not by
# themselves establish that these factors cause churn.

# %% [markdown]
# ##  Exploratory Data Analysis Part 2
#
# In this section, we explore numerical and service-related features
# to identify patterns associated with customer churn.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/customer_churn_cleaned.csv")

print("Dataset loaded successfully!")
df.head()
# Out:
# Dataset loaded successfully!
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(data=df, x="Churn", y="tenure")

plt.title("Customer Tenure by Churn Status")
plt.xlabel("Churn")
plt.ylabel("Tenure (Months)")
plt.show()

# %%
df.groupby("Churn")["tenure"].median()
# Out:
# Churn
# No     38.0
# Yes    10.0
# Name: tenure, dtype: float64

# %% [markdown]
# ### Observation: Customer Tenure vs Churn
#
# - Customers who churn generally have a **shorter tenure** compared to customers who do not churn.
# - The median tenure of churned customers is around **10 months**, while the median tenure of non-churned customers is around **38 months**.
# - This suggests that **newer customers are associated with a higher likelihood of churn**, while long-term customers are more likely to remain with the company.
# - Therefore, `tenure` appears to be an important feature to consider when building the churn prediction model.

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(data=df, x="Churn", y="MonthlyCharges")

plt.title("Monthly Charges by Churn Status")
plt.xlabel("Churn")
plt.ylabel("Monthly Charges")
plt.show()

# %%
df.groupby("Churn")["MonthlyCharges"].mean()
# Out:
# Churn
# No     61.307408
# Yes    74.441332
# Name: MonthlyCharges, dtype: float64

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(data=df, x="Churn", y="TotalCharges")

plt.title("Total Charges by Churn Status")
plt.xlabel("Churn")
plt.ylabel("Total Charges")
plt.show()

# %%
df.groupby("Churn")["TotalCharges"].median()
# Out:
# Churn
# No     1683.60
# Yes     703.55
# Name: TotalCharges, dtype: float64

# %%
plt.figure(figsize=(8, 5))

sns.countplot(
    data=df,
    x="InternetService",
    hue="Churn"
)

plt.title("Churn by Internet Service")
plt.xlabel("Internet Service")
plt.ylabel("Number of Customers")
plt.show()

# %%
pd.crosstab(
    df["InternetService"],
    df["Churn"],
    normalize="index"
) * 100
# Out:
# Churn                   No        Yes
# InternetService
# DSL              81.001656  18.998344
# Fiber optic      58.107235  41.892765
# No               92.565789   7.434211

# %%
plt.figure(figsize=(8, 5))

sns.countplot(
    data=df,
    x="TechSupport",
    hue="Churn"
)

plt.title("Churn by Tech Support")
plt.xlabel("Tech Support")
plt.ylabel("Number of Customers")
plt.show()

# %%
pd.crosstab(
    df["TechSupport"],
    df["Churn"],
    normalize="index"
) * 100
# Out:
# Churn                       No        Yes
# TechSupport
# No                   58.352535  41.647465
# No internet service  92.565789   7.434211
# Yes                  84.803922  15.196078

# %%
plt.figure(figsize=(8, 5))

sns.countplot(
    data=df,
    x="OnlineSecurity",
    hue="Churn"
)

plt.title("Churn by Online Security")
plt.xlabel("Online Security")
plt.ylabel("Number of Customers")
plt.show()

# %%
pd.crosstab(
    df["OnlineSecurity"],
    df["Churn"],
    normalize="index"
) * 100
# Out:
# Churn                       No        Yes
# OnlineSecurity
# No                   58.221333  41.778667
# No internet service  92.565789   7.434211
# Yes                  85.359801  14.640199

# %%
sns.countplot(
    data=df,
    x="PaperlessBilling",
    hue="Churn"
)

plt.title("Churn by Paperless Billing")
plt.xlabel("Paperless Billing")
plt.ylabel("Number of Customers")
plt.show()

# %% [markdown]
# ##  Key Findings
#
# - Customer tenure shows differences between churned and non-churned customers.
# - Monthly charges show differences across churn groups.
# - Internet service type is associated with different churn rates.
# - Tech support and online security show noticeable differences across churn groups.
# - These relationships are associations observed in the dataset and do not by themselves establish causation.
